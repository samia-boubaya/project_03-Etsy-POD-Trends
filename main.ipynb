# %% [markdown]
# ## Project 03: Etsy POD Trends Web scrapping & Analysis
# ---

# %% [markdown]
# ### Web Scrapping
# ----

# %% [markdown]
# ### Insights
# ---

# %% [markdown]
# ### Data visualization
# ----

# %% [markdown]
# #### Best selling POD product using Google Trends
# Which one among these products was researched on google the most 2023-2025
#
# ``` T-shirt ```
# ``` Tote bag ```
# ``` Mug ```
# ``` ... ```

# %% [markdown]
# ##### bars plot
